# %% [markdown]
# # Recognition of abnormality from Breast Thermograms Using ConvXGB
#
# ## Table of Contents
# - [1 - Packages](#1)
# - [2 - Pre - Processing ( Anisotropic Diffusion Filtering)](#2)
# - [3 - Load the Dataset](#3)
# - [4 - Test and Train Data](#4)
# - [5 - CNN Baseline Model](#5)
# - [6 - Json File ( For Storing Weights)](#6)
# - [7 - Loading CNN Model](#7)
# - [8 - XGBoost](#8)
# - [9 - Evaluation Metric](#9)

# %% [markdown]
# <a name='1'></a>
# # 1 - Packages

# %%
import numpy as np
import os
import pickle
import keras
from scipy import stats
import tensorflow as tf
import xgboost as xgb
from datetime import datetime
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import optimizers
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import cv2
import warnings
from keras.models import model_from_json

# %% [markdown]
# <a name='2'></a>
# # 2- Pre - Processing ( Anisotropic Diffusion Filtering)

# %%
def anisodiff(img,niter=4,kappa=50,gamma=0.1,step=(1.,1.),option=1,ploton=False):
   
    # ...you could always diffuse each color channel independently if you
    # really want
    img = img[150:440, 50:550]
    if img.ndim == 3:
        warnings.warn("Only grayscale images allowed, converting to 2D matrix")
        img = img.mean(2)

    # initialize output array
    img = img.astype('float32')
    imgout = img.copy()

    # initialize some internal variables
    deltaS = np.zeros_like(imgout)
    deltaE = deltaS.copy()
    NS = deltaS.copy()
    EW = deltaS.copy()
    gS = np.ones_like(imgout)
    gE = gS.copy()

    # create the plot figure, if requested
    if ploton:
        import pylab as pl
        from time import sleep

        fig = pl.figure(figsize=(20,5.5),num="Anisotropic diffusion")
        ax1,ax2 = fig.add_subplot(1,2,1),fig.add_subplot(1,2,2)

        ax1.imshow(img,interpolation='nearest')
        ih = ax2.imshow(imgout,interpolation='nearest',animated=True)
        ax1.set_title("Original image")
        ax2.set_title("Iteration 0")

        fig.canvas.draw()

    for ii in range(niter):

        # calculate the diffs
        deltaS[:-1,: ] = np.diff(imgout,axis=0)
        deltaE[: ,:-1] = np.diff(imgout,axis=1)

        # conduction gradients (only need to compute one per dim!)
        if option == 1:
            gS = np.exp(-(deltaS/kappa)**2.)/step[0]
            gE = np.exp(-(deltaE/kappa)**2.)/step[1]
        elif option == 2:
            gS = 1./(1.+(deltaS/kappa)**2.)/step[0]
            gE = 1./(1.+(deltaE/kappa)**2.)/step[1]

        # update matrices
        E = gE*deltaE
        S = gS*deltaS

        # subtract a copy that has been shifted 'North/West' by one
        # pixel. don't as questions. just do it. trust me.
        NS[:] = S
        EW[:] = E
        NS[1:,:] -= S[:-1,:]
        EW[:,1:] -= E[:,:-1]

        # update the image
        imgout += gamma*(NS+EW)

        if ploton:
            iterstring = "Iteration %i" %(ii+1)
            ih.set_data(imgout)
            ax2.set_title(iterstring)
            fig.canvas.draw()
            # sleep(0.01)

    return imgout

# %% [markdown]
# <a name='3'></a>
# # 3 - Load the Dataset
#
# The Data Set Consists of total 117 Breast Thermal Images From visual DMI - IR Data Set(https://visual.ic.uff.br/dmi/).
# - 86 Images (Without Cancer)
# - 32 Images (With Cancer)
# - Data Set Zip Folder (https://drive.google.com/file/d/1ILEfL8uose4R7BQGQGZevCw7SCiel62o/view?usp=sharing)

# %%
path_test = "C:/Users/rsvmu/Downloads/Data_2"
CATEGORIES = ["Withcancer","Withoutcancer"]
IMG_SIZE_X = 480
IMG_SIZE_Y = 640

# %% [markdown]
# **Note:** Here, The createTrainingData Fucntion besides loading/creating the data for model the two main steps are taking place before giving it to the model:
#  - First step - Is converting the RGB image **(480, 640, 3)** to Gray_scale **(480, 640)**
#  - Second step - Using the above function **anisdiff** filter and apply that on Gray_scale Images.
#  - The Input Image Shape is **(290,500)**

# %%
training = []
def createTrainingData():
    for category in CATEGORIES:
        path = os.path.join(path_test, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path,img),0) #Changing RGB to Gray_Scale 
            aniso = anisodiff(img_array,) # Applying anistropic Diffusion Filter to Gray_scale Images
            new_array = cv2.resize(aniso, (IMG_SIZE_X, IMG_SIZE_Y))
            training.append([new_array, class_num])
createTrainingData()

# %%
X =[]
y =[]
for features, label in training:
    X.append(features)
    y.append(label)
X = np.array(X).reshape(-1, IMG_SIZE_X, IMG_SIZE_Y)

# %%
X = X.astype('float32')
X /= 255
from keras.utils import np_utils
Y = np_utils.to_categorical(y, 2)
print(Y[5])
print(Y.shape)
# Out:
# [1. 0.]
# (215, 2)

# %% [markdown]
# <a name='4'></a>
# # 4 - Test and Train Data
# - Test Data - 20 Percent of Whole data 102 Images

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 4)

# %%
batch_size = 2
nb_classes = 2
nb_epochs = 20
img_rows, img_columns = 480, 640
img_channel = 3
nb_filters = 32
nb_pool = 5
nb_conv = 5

# %% [markdown]
# <a name='5'></a>
# # 5 - CNN Baseline Model
# - I have first Used two Convolutional Layers with no padding and for hidden layers took RELU Activation Function and for Output layer we took sigmoid Function.

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu,
#                            input_shape=(480, 640,1)),
#     tf.keras.layers.MaxPooling2D((2, 2), strides=1),
#     tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu),
#     tf.keras.layers.MaxPooling2D((2, 2), strides=1),
#     tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu),
#     tf.keras.layers.MaxPooling2D((2, 2), strides=1),
#     tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu),
#     tf.keras.layers.MaxPooling2D((2, 2), strides=1),
#     tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu),
#     tf.keras.layers.MaxPooling2D((2, 2), strides=1),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(128, activation=tf.nn.relu),
#     tf.keras.layers.Dense(1,  activation=tf.nn.sigmoid)
    
# ])

# %%
model = Sequential()
# Input Layer
# filters = Similar to number of Neurons, kernel_size = (3,3), strides = (1,1), padding = 'same'(zero padding), activation = 'relu'
model.add(Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = 'same', activation = 'LeakyReLU',
                    input_shape = (480, 640,1)))
# model.add(BatchNormalization(momentum=0.9, epsilon=1e-5, gamma_initializer="uniform"))
#     # MaxPooling
model.add(MaxPooling2D())
model.add(Dropout(0.7))
    # Conv2D - II
model.add(Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = 'same', activation = 'relu'))
# model.add(BatchNormalization(momentum=0.9, epsilon=1e-5, gamma_initializer="uniform"))
    # MaxPooling
model.add(MaxPooling2D())
# model.add(Dropout(0.5))   
    # Conv2D - III
model.add(Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = 'same', activation = 'LeakyReLU'))
# model.add(BatchNormalization(momentum=0.9, epsilon=1e-5, gamma_initializer="uniform"))
    # MaxPooling
model.add(MaxPooling2D())

# model.add(Dropout(0.5))    
    # Flatten Layer
model.add(Flatten())
    
    # Fully Connected Layer
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# model.fit(X_train, y_train, batch_size = batch_size, epochs = nb_epochs, verbose = 1, validation_data = (X_test, y_test))

# %%
from tensorflow.keras import callbacks
filepath = "path/Mask_BestModel.hdf5"
checkpoint = callbacks.ModelCheckpoint(filepath, monitor='val_loss', save_best_model = True, mode = 'min', verbose = 1)
checkpoint

# %%
history = model.fit(X_train, y_train, batch_size = batch_size, epochs = nb_epochs, validation_data = (X_test, y_test), callbacks = [checkpoint], verbose = 1)
# Out:
# Epoch 1/20
# 81/81 [==============================] - ETA: 0s - loss: 6.2913 - accuracy: 0.6398
# Epoch 1: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 129s 2s/step - loss: 6.2913 - accuracy: 0.6398 - val_loss: 0.6410 - val_accuracy: 0.8333
# Epoch 2/20
# 81/81 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.7329
# Epoch 2: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 115s 1s/step - loss: 0.6846 - accuracy: 0.7329 - val_loss: 1.9117 - val_accuracy: 0.1667
# Epoch 3/20
# 81/81 [==============================] - ETA: 0s - loss: 0.5702 - accuracy: 0.7826
# Epoch 3: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 95s 1s/step - loss: 0.5702 - accuracy: 0.7826 - val_loss: 5.4198 - val_accuracy: 0.1667
# Epoch 4/20
# 81/81 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.8012
# Epoch 4: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.5193 - accuracy: 0.8012 - val_loss: 6.8136 - val_accuracy: 0.1667
# Epoch 5/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7950
# Epoch 5: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 87s 1s/step - loss: 0.4857 - accuracy: 0.7950 - val_loss: 6.7055 - val_accuracy: 0.1667
# Epoch 6/20
# 81/81 [==============================] - ETA: 0s - loss: 0.7457 - accuracy: 0.7516
# Epoch 6: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 87s 1s/step - loss: 0.7457 - accuracy: 0.7516 - val_loss: 0.6051 - val_accuracy: 0.8333
# Epoch 7/20
# 81/81 [==============================] - ETA: 0s - loss: 0.5291 - accuracy: 0.7950
# Epoch 7: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.5291 - accuracy: 0.7950 - val_loss: 0.4536 - val_accuracy: 0.8333
# Epoch 8/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4889 - accuracy: 0.8012
# Epoch 8: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 87s 1s/step - loss: 0.4889 - accuracy: 0.8012 - val_loss: 0.8658 - val_accuracy: 0.1852
# Epoch 9/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4499 - accuracy: 0.7764
# Epoch 9: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.4499 - accuracy: 0.7764 - val_loss: 0.4869 - val_accuracy: 0.8333
# Epoch 10/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4536 - accuracy: 0.8261
# Epoch 10: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.4536 - accuracy: 0.8261 - val_loss: 1.6873 - val_accuracy: 0.1667
# Epoch 11/20
# 81/81 [==============================] - ETA: 0s - loss: 0.5107 - accuracy: 0.7950
# Epoch 11: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.5107 - accuracy: 0.7950 - val_loss: 0.4474 - val_accuracy: 0.8333
# Epoch 12/20
# 81/81 [==============================] - ETA: 0s - loss: 0.5041 - accuracy: 0.7640
# Epoch 12: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.5041 - accuracy: 0.7640 - val_loss: 1.1755 - val_accuracy: 0.2037
# Epoch 13/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4568 - accuracy: 0.8137
# Epoch 13: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.4568 - accuracy: 0.8137 - val_loss: 0.6800 - val_accuracy: 0.4259
# Epoch 14/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4330 - accuracy: 0.8261
# Epoch 14: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.4330 - accuracy: 0.8261 - val_loss: 0.6841 - val_accuracy: 0.6296
# Epoch 15/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.8137
# Epoch 15: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 87s 1s/step - loss: 0.4032 - accuracy: 0.8137 - val_loss: 1.0078 - val_accuracy: 0.4815
# Epoch 16/20
# 81/81 [==============================] - ETA: 0s - loss: 0.4025 - accuracy: 0.8261
# Epoch 16: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 85s 1s/step - loss: 0.4025 - accuracy: 0.8261 - val_loss: 2.1776 - val_accuracy: 0.2963
# Epoch 17/20
# 81/81 [==============================] - ETA: 0s - loss: 0.3733 - accuracy: 0.8571
# Epoch 17: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.3733 - accuracy: 0.8571 - val_loss: 0.4742 - val_accuracy: 0.8148
# Epoch 18/20
# 81/81 [==============================] - ETA: 0s - loss: 0.3581 - accuracy: 0.8758
# Epoch 18: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 87s 1s/step - loss: 0.3581 - accuracy: 0.8758 - val_loss: 0.5362 - val_accuracy: 0.7407
# Epoch 19/20
# 81/81 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.8882
# Epoch 19: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.3104 - accuracy: 0.8882 - val_loss: 1.5208 - val_accuracy: 0.2963
# Epoch 20/20
# 81/81 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8882
# Epoch 20: saving model to path\Mask_BestModel.hdf5
# 81/81 [==============================] - 86s 1s/step - loss: 0.2920 - accuracy: 0.8882 - val_loss: 0.6757 - val_accuracy: 0.6852

# %% [markdown]
# <a name='6'></a>
# # 6 - Json File ( For Storing Weights)
# - After Completeing the CNN we are storing the weights into json file and read the file to give this weights to a XgBoost.

# %%
json_model = model.to_json()

# %%
with open("model.json", "w") as json_file:
    json_file.write(json_model)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
mean = np.mean(X_train,axis=(0,1,2))
std = np.std(X_train,axis=(0,1,2))
X_train = (X_train-mean)/(std+1e-7)
X_test = (X_test-mean)/(std+1e-7)

# %% [markdown]
# <a name='7'></a>
# # 7 - Loading CNN Model

# %%
def load_cnn_model(X_test, y_test):
	model.load_weights("path/Mask_BestModel.hdf5")
	opt_rms = optimizers.Adam(learning_rate=0.001,decay=1e-6)
	model.compile(
		loss='binary_crossentropy',
		optimizer=opt_rms,
		metrics=['accuracy'])
	'''
	y_test_ = np_utils.to_categorical(y_test, 10)
	scores = loaded_model.evaluate(X_test, y_test_, batch_size=128, verbose=1)
	print('\nTest result: %.3f loss: %.3f\n' % (scores[1]*100,scores[0]))
	'''
	return model

# %%
cnn_model = load_cnn_model(X_test, y_test)
print("Loaded CNN model from disk")
# Out:
# Loaded CNN model from disk

# %%
def get_feature_layer(model, data):
	
	total_layers = len(model.layers)
	fl_index = total_layers - 2
	feature_layer_model = keras.Model(
		inputs=model.input,
		outputs=model.get_layer(index=fl_index).output)
	
	feature_layer_output = feature_layer_model.predict(data)
	
	return feature_layer_output

# %%
X_train_cnn =  get_feature_layer(cnn_model, X_train)
print("Features extracted of training data")
X_test_cnn = get_feature_layer(cnn_model, X_test)
print("Features extracted of test data\n")
# Out:
# Features extracted of training data
# Features extracted of test data

# %% [markdown]
# <a name='8'></a>
# # 8 - XGBoost

# %%
def xgb_model(X_train, y_train, X_test, y_test):

	dtrain = xgb.DMatrix(
		X_train,
		label=y_train
	)

	dtest = xgb.DMatrix(
		X_test,
		label=y_test
	)

	results = {}

	params = {
		'max_depth':5,
		'eta':0.05,
		'objective':'multi:softprob',
        'min_child_weight':2,
        'learning_rate':0.5,
		'num_class':2,
		'eval_metric':'merror'
	}

	watchlist = [(dtrain, 'train'),(dtest, 'eval')]
	n_round = 400

	model = xgb.train(
		params,
		dtrain,
		n_round,
		watchlist,
		evals_result=results)

	pickle.dump(model, open("cnn_xgboost_final.pickle.dat", "wb"))

	return model

# %% [markdown]
# <a name='9'></a>
# # 9 - Evalution Metric
#
# - merror - Multiclass classification error rate. It is calculated as **#(wrong cases)/#(all cases)**

# %%
print("Build and save of CNN-XGBoost Model.")
model = xgb_model(X_train_cnn, y_train, X_test_cnn, y_test)
# Out:
# Build and save of CNN-XGBoost Model.
# [0]	train-merror:0.03106	eval-merror:0.22222
# [1]	train-merror:0.01863	eval-merror:0.20370
# [2]	train-merror:0.02484	eval-merror:0.22222
# [3]	train-merror:0.01242	eval-merror:0.20370
# [4]	train-merror:0.01242	eval-merror:0.20370
# [5]	train-merror:0.01242	eval-merror:0.20370
# [6]	train-merror:0.01242	eval-merror:0.20370
# [7]	train-merror:0.01242	eval-merror:0.20370
# [8]	train-merror:0.01242	eval-merror:0.20370
# [9]	train-merror:0.00621	eval-merror:0.22222
# [10]	train-merror:0.00621	eval-merror:0.22222
# [11]	train-merror:0.00621	eval-merror:0.22222
# [12]	train-merror:0.00621	eval-merror:0.22222
# [13]	train-merror:0.00000	eval-merror:0.20370
# [14]	train-merror:0.00000	eval-merror:0.22222
# [15]	train-merror:0.00000	eval-merror:0.22222
# [16]	train-merror:0.00000	eval-merror:0.20370
# [17]	train-merror:0.00000	eval-merror:0.20370
# [18]	train-merror:0.00000	eval-merror:0.20370
# [19]	train-merror:0.00000	eval-merror:0.20370
# [20]	train-merror:0.00000	eval-merror:0.20370
# [21]	train-merror:0.00000	eval-merror:0.20370
# [22]	train-merror:0.00000	eval-merror:0.20370
# [23]	train-merror:0.00000	eval-merror:0.20370
# [24]	train-merror:0.00000	eval-merror:0.18519
# [25]	train-merror:0.00000	eval-merror:0.20370
# [26]	train-merror:0.00000	eval-merror:0.18519
# [27]	train-merror:0.00000	eval-merror:0.22222
# [28]	train-merror:0.00000	eval-merror:0.20370
# [29]	train-merror:0.00000	eval-merror:0.20370
# [30]	train-merror:0.00000	eval-merror:0.20370
# [31]	train-merror:0.00000	eval-merror:0.20370
# [32]	train-merror:0.00000	eval-merror:0.22222
# [33]	train-merror:0.00000	eval-merror:0.20370
# [34]	train-merror:0.00000	eval-merror:0.22222
# [35]	train-merror:0.00000	eval-merror:0.22222
# [36]	train-merror:0.00000	eval-merror:0.22222
# [37]	train-merror:0.00000	eval-merror:0.22222
# [38]	train-merror:0.00000	eval-merror:0.22222
# [39]	train-merror:0.00000	eval-merror:0.24074
# [40]	train-merror:0.00000	eval-merror:0.22222
# [41]	train-merror:0.00000	eval-merror:0.24074
# [42]	train-merror:0.00000	eval-merror:0.22222
# [43]	train-merror:0.00000	eval-merror:0.24074
# [44]	train-merror:0.00000	eval-merror:0.24074
# [45]	train-merror:0.00000	eval-merror:0.24074
# [46]	train-merror:0.00000	eval-merror:0.24074
# [47]	train-merror:0.00000	eval-merror:0.24074
# [48]	train-merror:0.00000	eval-merror:0.24074
# [49]	train-merror:0.00000	eval-merror:0.24074
# [50]	train-merror:0.00000	eval-merror:0.24074
# [51]	train-merror:0.00000	eval-merror:0.24074
# [52]	train-merror:0.00000	eval-merror:0.24074
# [53]	train-merror:0.00000	eval-merror:0.24074
# [54]	train-merror:0.00000	eval-merror:0.24074
# [55]	train-merror:0.00000	eval-merror:0.24074
# [56]	train-merror:0.00000	eval-merror:0.24074
# [57]	train-merror:0.00000	eval-merror:0.24074
# [58]	train-merror:0.00000	eval-merror:0.24074
# [59]	train-merror:0.00000	eval-merror:0.24074
# [60]	train-merror:0.00000	eval-merror:0.24074
# [61]	train-merror:0.00000	eval-merror:0.24074
# [62]	train-merror:0.00000	eval-merror:0.24074
# [63]	train-merror:0.00000	eval-merror:0.24074
# C:\Users\rsvmu\anaconda3\lib\site-packages\xgboost\core.py:525: FutureWarning: Pass `evals` as keyword args.  Passing these as positional arguments will be considered as error in future releases.
#   warnings.warn(
# [64]	train-merror:0.00000	eval-merror:0.24074
# [65]	train-merror:0.00000	eval-merror:0.24074
# [66]	train-merror:0.00000	eval-merror:0.24074
# [67]	train-merror:0.00000	eval-merror:0.24074
# [68]	train-merror:0.00000	eval-merror:0.24074
# [69]	train-merror:0.00000	eval-merror:0.24074
# [70]	train-merror:0.00000	eval-merror:0.24074
# [71]	train-merror:0.00000	eval-merror:0.24074
# [72]	train-merror:0.00000	eval-merror:0.24074
# [73]	train-merror:0.00000	eval-merror:0.24074
# [74]	train-merror:0.00000	eval-merror:0.24074
# [75]	train-merror:0.00000	eval-merror:0.24074
# [76]	train-merror:0.00000	eval-merror:0.24074
# [77]	train-merror:0.00000	eval-merror:0.24074
# [78]	train-merror:0.00000	eval-merror:0.24074
# [79]	train-merror:0.00000	eval-merror:0.24074
# [80]	train-merror:0.00000	eval-merror:0.24074
# [81]	train-merror:0.00000	eval-merror:0.24074
# [82]	train-merror:0.00000	eval-merror:0.24074
# [83]	train-merror:0.00000	eval-merror:0.24074
# [84]	train-merror:0.00000	eval-merror:0.24074
# [85]	train-merror:0.00000	eval-merror:0.24074
# [86]	train-merror:0.00000	eval-merror:0.24074
# [87]	train-merror:0.00000	eval-merror:0.24074
# [88]	train-merror:0.00000	eval-merror:0.24074
# [89]	train-merror:0.00000	eval-merror:0.24074
# [90]	train-merror:0.00000	eval-merror:0.24074
# [91]	train-merror:0.00000	eval-merror:0.24074
# [92]	train-merror:0.00000	eval-merror:0.24074
# [93]	train-merror:0.00000	eval-merror:0.24074
# [94]	train-merror:0.00000	eval-merror:0.24074
# [95]	train-merror:0.00000	eval-merror:0.24074
# [96]	train-merror:0.00000	eval-merror:0.24074
# [97]	train-merror:0.00000	eval-merror:0.24074
# [98]	train-merror:0.00000	eval-merror:0.24074
# [99]	train-merror:0.00000	eval-merror:0.24074
# [100]	train-merror:0.00000	eval-merror:0.24074
# [101]	train-merror:0.00000	eval-merror:0.24074
# [102]	train-merror:0.00000	eval-merror:0.24074
# [103]	train-merror:0.00000	eval-merror:0.24074
# [104]	train-merror:0.00000	eval-merror:0.24074
# [105]	train-merror:0.00000	eval-merror:0.24074
# [106]	train-merror:0.00000	eval-merror:0.24074
# [107]	train-merror:0.00000	eval-merror:0.24074
# [108]	train-merror:0.00000	eval-merror:0.24074
# [109]	train-merror:0.00000	eval-merror:0.24074
# [110]	train-merror:0.00000	eval-merror:0.24074
# [111]	train-merror:0.00000	eval-merror:0.24074
# [112]	train-merror:0.00000	eval-merror:0.24074
# [113]	train-merror:0.00000	eval-merror:0.24074
# [114]	train-merror:0.00000	eval-merror:0.24074
# [115]	train-merror:0.00000	eval-merror:0.24074
# [116]	train-merror:0.00000	eval-merror:0.24074
# [117]	train-merror:0.00000	eval-merror:0.24074
# [118]	train-merror:0.00000	eval-merror:0.24074
# [119]	train-merror:0.00000	eval-merror:0.24074
# [120]	train-merror:0.00000	eval-merror:0.24074
# [121]	train-merror:0.00000	eval-merror:0.24074
# [122]	train-merror:0.00000	eval-merror:0.24074
# [123]	train-merror:0.00000	eval-merror:0.24074
# [124]	train-merror:0.00000	eval-merror:0.24074
# [125]	train-merror:0.00000	eval-merror:0.24074
# [126]	train-merror:0.00000	eval-merror:0.24074
# [127]	train-merror:0.00000	eval-merror:0.24074
# [128]	train-merror:0.00000	eval-merror:0.24074
# [129]	train-merror:0.00000	eval-merror:0.24074
# [130]	train-merror:0.00000	eval-merror:0.24074
# [131]	train-merror:0.00000	eval-merror:0.24074
# [132]	train-merror:0.00000	eval-merror:0.24074
# [133]	train-merror:0.00000	eval-merror:0.24074
# [134]	train-merror:0.00000	eval-merror:0.24074
# [135]	train-merror:0.00000	eval-merror:0.24074
# [136]	train-merror:0.00000	eval-merror:0.24074
# [137]	train-merror:0.00000	eval-merror:0.24074
# [138]	train-merror:0.00000	eval-merror:0.24074
# [139]	train-merror:0.00000	eval-merror:0.24074
# [140]	train-merror:0.00000	eval-merror:0.24074
# [141]	train-merror:0.00000	eval-merror:0.24074
# [142]	train-merror:0.00000	eval-merror:0.24074
# [143]	train-merror:0.00000	eval-merror:0.24074
# [144]	train-merror:0.00000	eval-merror:0.24074
# [145]	train-merror:0.00000	eval-merror:0.24074
# [146]	train-merror:0.00000	eval-merror:0.24074
# [147]	train-merror:0.00000	eval-merror:0.24074
# [148]	train-merror:0.00000	eval-merror:0.24074
# [149]	train-merror:0.00000	eval-merror:0.24074
# [150]	train-merror:0.00000	eval-merror:0.24074
# [151]	train-merror:0.00000	eval-merror:0.24074
# [152]	train-merror:0.00000	eval-merror:0.24074
# [153]	train-merror:0.00000	eval-merror:0.24074
# [154]	train-merror:0.00000	eval-merror:0.24074
# [155]	train-merror:0.00000	eval-merror:0.24074
# [156]	train-merror:0.00000	eval-merror:0.24074
# [157]	train-merror:0.00000	eval-merror:0.24074
# [158]	train-merror:0.00000	eval-merror:0.24074
# [159]	train-merror:0.00000	eval-merror:0.24074
# [160]	train-merror:0.00000	eval-merror:0.24074
# [161]	train-merror:0.00000	eval-merror:0.24074
# [162]	train-merror:0.00000	eval-merror:0.24074
# [163]	train-merror:0.00000	eval-merror:0.24074
# [164]	train-merror:0.00000	eval-merror:0.24074
# [165]	train-merror:0.00000	eval-merror:0.24074
# [166]	train-merror:0.00000	eval-merror:0.24074
# [167]	train-merror:0.00000	eval-merror:0.24074
# [168]	train-merror:0.00000	eval-merror:0.24074
# [169]	train-merror:0.00000	eval-merror:0.24074
# [170]	train-merror:0.00000	eval-merror:0.24074
# [171]	train-merror:0.00000	eval-merror:0.24074
# [172]	train-merror:0.00000	eval-merror:0.24074
# [173]	train-merror:0.00000	eval-merror:0.24074
# [174]	train-merror:0.00000	eval-merror:0.24074
# [175]	train-merror:0.00000	eval-merror:0.24074
# [176]	train-merror:0.00000	eval-merror:0.24074
# [177]	train-merror:0.00000	eval-merror:0.24074
# [178]	train-merror:0.00000	eval-merror:0.24074
# [179]	train-merror:0.00000	eval-merror:0.24074
# [180]	train-merror:0.00000	eval-merror:0.24074
# [181]	train-merror:0.00000	eval-merror:0.24074
# [182]	train-merror:0.00000	eval-merror:0.24074
# [183]	train-merror:0.00000	eval-merror:0.24074
# [184]	train-merror:0.00000	eval-merror:0.24074
# [185]	train-merror:0.00000	eval-merror:0.24074
# [186]	train-merror:0.00000	eval-merror:0.24074
# [187]	train-merror:0.00000	eval-merror:0.24074
# [188]	train-merror:0.00000	eval-merror:0.24074
# [189]	train-merror:0.00000	eval-merror:0.24074
# [190]	train-merror:0.00000	eval-merror:0.24074
# [191]	train-merror:0.00000	eval-merror:0.24074
# [192]	train-merror:0.00000	eval-merror:0.24074
# [193]	train-merror:0.00000	eval-merror:0.24074
# [194]	train-merror:0.00000	eval-merror:0.24074
# [195]	train-merror:0.00000	eval-merror:0.24074
# [196]	train-merror:0.00000	eval-merror:0.24074
# [197]	train-merror:0.00000	eval-merror:0.24074
# [198]	train-merror:0.00000	eval-merror:0.24074
# [199]	train-merror:0.00000	eval-merror:0.24074
# [200]	train-merror:0.00000	eval-merror:0.24074
# [201]	train-merror:0.00000	eval-merror:0.24074
# [202]	train-merror:0.00000	eval-merror:0.24074
# [203]	train-merror:0.00000	eval-merror:0.24074
# [204]	train-merror:0.00000	eval-merror:0.24074
# [205]	train-merror:0.00000	eval-merror:0.24074
# [206]	train-merror:0.00000	eval-merror:0.24074
# [207]	train-merror:0.00000	eval-merror:0.24074
# [208]	train-merror:0.00000	eval-merror:0.24074
# [209]	train-merror:0.00000	eval-merror:0.24074
# [210]	train-merror:0.00000	eval-merror:0.24074
# [211]	train-merror:0.00000	eval-merror:0.24074
# [212]	train-merror:0.00000	eval-merror:0.24074
# [213]	train-merror:0.00000	eval-merror:0.24074
# [214]	train-merror:0.00000	eval-merror:0.24074
# [215]	train-merror:0.00000	eval-merror:0.24074
# [216]	train-merror:0.00000	eval-merror:0.24074
# [217]	train-merror:0.00000	eval-merror:0.24074
# [218]	train-merror:0.00000	eval-merror:0.24074
# [219]	train-merror:0.00000	eval-merror:0.24074
# [220]	train-merror:0.00000	eval-merror:0.24074
# [221]	train-merror:0.00000	eval-merror:0.24074
# [222]	train-merror:0.00000	eval-merror:0.24074
# [223]	train-merror:0.00000	eval-merror:0.24074
# [224]	train-merror:0.00000	eval-merror:0.24074
# [225]	train-merror:0.00000	eval-merror:0.25926
# [226]	train-merror:0.00000	eval-merror:0.25926
# [227]	train-merror:0.00000	eval-merror:0.25926
# [228]	train-merror:0.00000	eval-merror:0.25926
# [229]	train-merror:0.00000	eval-merror:0.25926
# [230]	train-merror:0.00000	eval-merror:0.25926
# [231]	train-merror:0.00000	eval-merror:0.25926
# [232]	train-merror:0.00000	eval-merror:0.25926
# [233]	train-merror:0.00000	eval-merror:0.25926
# [234]	train-merror:0.00000	eval-merror:0.25926
# [235]	train-merror:0.00000	eval-merror:0.25926
# [236]	train-merror:0.00000	eval-merror:0.25926
# [237]	train-merror:0.00000	eval-merror:0.25926
# [238]	train-merror:0.00000	eval-merror:0.25926
# [239]	train-merror:0.00000	eval-merror:0.25926
# [240]	train-merror:0.00000	eval-merror:0.25926
# [241]	train-merror:0.00000	eval-merror:0.25926
# [242]	train-merror:0.00000	eval-merror:0.25926
# [243]	train-merror:0.00000	eval-merror:0.25926
# [244]	train-merror:0.00000	eval-merror:0.25926
# [245]	train-merror:0.00000	eval-merror:0.25926
# [246]	train-merror:0.00000	eval-merror:0.25926
# [247]	train-merror:0.00000	eval-merror:0.25926
# [248]	train-merror:0.00000	eval-merror:0.25926
# [249]	train-merror:0.00000	eval-merror:0.25926
# [250]	train-merror:0.00000	eval-merror:0.25926
# [251]	train-merror:0.00000	eval-merror:0.25926
# [252]	train-merror:0.00000	eval-merror:0.25926
# [253]	train-merror:0.00000	eval-merror:0.25926
# [254]	train-merror:0.00000	eval-merror:0.25926
# [255]	train-merror:0.00000	eval-merror:0.25926
# [256]	train-merror:0.00000	eval-merror:0.25926
# [257]	train-merror:0.00000	eval-merror:0.25926
# [258]	train-merror:0.00000	eval-merror:0.25926
# [259]	train-merror:0.00000	eval-merror:0.25926
# [260]	train-merror:0.00000	eval-merror:0.25926
# [261]	train-merror:0.00000	eval-merror:0.25926
# [262]	train-merror:0.00000	eval-merror:0.25926
# [263]	train-merror:0.00000	eval-merror:0.25926
# [264]	train-merror:0.00000	eval-merror:0.25926
# [265]	train-merror:0.00000	eval-merror:0.25926
# [266]	train-merror:0.00000	eval-merror:0.25926
# [267]	train-merror:0.00000	eval-merror:0.25926
# [268]	train-merror:0.00000	eval-merror:0.25926
# [269]	train-merror:0.00000	eval-merror:0.25926
# [270]	train-merror:0.00000	eval-merror:0.25926
# [271]	train-merror:0.00000	eval-merror:0.25926
# [272]	train-merror:0.00000	eval-merror:0.25926
# [273]	train-merror:0.00000	eval-merror:0.25926
# [274]	train-merror:0.00000	eval-merror:0.25926
# [275]	train-merror:0.00000	eval-merror:0.25926
# [276]	train-merror:0.00000	eval-merror:0.25926
# [277]	train-merror:0.00000	eval-merror:0.25926
# [278]	train-merror:0.00000	eval-merror:0.25926
# [279]	train-merror:0.00000	eval-merror:0.25926
# [280]	train-merror:0.00000	eval-merror:0.25926
# [281]	train-merror:0.00000	eval-merror:0.25926
# [282]	train-merror:0.00000	eval-merror:0.25926
# [283]	train-merror:0.00000	eval-merror:0.25926
# [284]	train-merror:0.00000	eval-merror:0.25926
# [285]	train-merror:0.00000	eval-merror:0.25926
# [286]	train-merror:0.00000	eval-merror:0.25926
# [287]	train-merror:0.00000	eval-merror:0.25926
# [288]	train-merror:0.00000	eval-merror:0.25926
# [289]	train-merror:0.00000	eval-merror:0.25926
# [290]	train-merror:0.00000	eval-merror:0.25926
# [291]	train-merror:0.00000	eval-merror:0.25926
# [292]	train-merror:0.00000	eval-merror:0.25926
# [293]	train-merror:0.00000	eval-merror:0.25926
# [294]	train-merror:0.00000	eval-merror:0.25926
# [295]	train-merror:0.00000	eval-merror:0.25926
# [296]	train-merror:0.00000	eval-merror:0.25926
# [297]	train-merror:0.00000	eval-merror:0.25926
# [298]	train-merror:0.00000	eval-merror:0.25926
# [299]	train-merror:0.00000	eval-merror:0.25926
# [300]	train-merror:0.00000	eval-merror:0.25926
# [301]	train-merror:0.00000	eval-merror:0.25926
# [302]	train-merror:0.00000	eval-merror:0.25926
# [303]	train-merror:0.00000	eval-merror:0.25926
# [304]	train-merror:0.00000	eval-merror:0.25926
# [305]	train-merror:0.00000	eval-merror:0.25926
# [306]	train-merror:0.00000	eval-merror:0.25926
# [307]	train-merror:0.00000	eval-merror:0.25926
# [308]	train-merror:0.00000	eval-merror:0.25926
# [309]	train-merror:0.00000	eval-merror:0.25926
# [310]	train-merror:0.00000	eval-merror:0.25926
# [311]	train-merror:0.00000	eval-merror:0.25926
# [312]	train-merror:0.00000	eval-merror:0.25926
# [313]	train-merror:0.00000	eval-merror:0.25926
# [314]	train-merror:0.00000	eval-merror:0.25926
# [315]	train-merror:0.00000	eval-merror:0.25926
# [316]	train-merror:0.00000	eval-merror:0.25926
# [317]	train-merror:0.00000	eval-merror:0.25926
# [318]	train-merror:0.00000	eval-merror:0.25926
# [319]	train-merror:0.00000	eval-merror:0.25926
# [320]	train-merror:0.00000	eval-merror:0.25926
# [321]	train-merror:0.00000	eval-merror:0.25926
# [322]	train-merror:0.00000	eval-merror:0.25926
# [323]	train-merror:0.00000	eval-merror:0.25926
# [324]	train-merror:0.00000	eval-merror:0.25926
# [325]	train-merror:0.00000	eval-merror:0.25926
# [326]	train-merror:0.00000	eval-merror:0.25926
# [327]	train-merror:0.00000	eval-merror:0.25926
# [328]	train-merror:0.00000	eval-merror:0.25926
# [329]	train-merror:0.00000	eval-merror:0.25926
# [330]	train-merror:0.00000	eval-merror:0.25926
# [331]	train-merror:0.00000	eval-merror:0.25926
# [332]	train-merror:0.00000	eval-merror:0.25926
# [333]	train-merror:0.00000	eval-merror:0.25926
# [334]	train-merror:0.00000	eval-merror:0.25926
# [335]	train-merror:0.00000	eval-merror:0.25926
# [336]	train-merror:0.00000	eval-merror:0.25926
# [337]	train-merror:0.00000	eval-merror:0.25926
# [338]	train-merror:0.00000	eval-merror:0.25926
# [339]	train-merror:0.00000	eval-merror:0.25926
# [340]	train-merror:0.00000	eval-merror:0.25926
# [341]	train-merror:0.00000	eval-merror:0.25926
# [342]	train-merror:0.00000	eval-merror:0.25926
# [343]	train-merror:0.00000	eval-merror:0.25926
# [344]	train-merror:0.00000	eval-merror:0.25926
# [345]	train-merror:0.00000	eval-merror:0.25926
# [346]	train-merror:0.00000	eval-merror:0.25926
# [347]	train-merror:0.00000	eval-merror:0.25926
# [348]	train-merror:0.00000	eval-merror:0.25926
# [349]	train-merror:0.00000	eval-merror:0.25926
# [350]	train-merror:0.00000	eval-merror:0.25926
# [351]	train-merror:0.00000	eval-merror:0.25926
# [352]	train-merror:0.00000	eval-merror:0.25926
# [353]	train-merror:0.00000	eval-merror:0.25926
# [354]	train-merror:0.00000	eval-merror:0.25926
# [355]	train-merror:0.00000	eval-merror:0.25926
# [356]	train-merror:0.00000	eval-merror:0.25926
# [357]	train-merror:0.00000	eval-merror:0.25926
# [358]	train-merror:0.00000	eval-merror:0.25926
# [359]	train-merror:0.00000	eval-merror:0.25926
# [360]	train-merror:0.00000	eval-merror:0.25926
# [361]	train-merror:0.00000	eval-merror:0.25926
# [362]	train-merror:0.00000	eval-merror:0.25926
# [363]	train-merror:0.00000	eval-merror:0.25926
# [364]	train-merror:0.00000	eval-merror:0.25926
# [365]	train-merror:0.00000	eval-merror:0.25926
# [366]	train-merror:0.00000	eval-merror:0.25926
# [367]	train-merror:0.00000	eval-merror:0.25926
# [368]	train-merror:0.00000	eval-merror:0.25926
# [369]	train-merror:0.00000	eval-merror:0.25926
# [370]	train-merror:0.00000	eval-merror:0.25926
# [371]	train-merror:0.00000	eval-merror:0.25926
# [372]	train-merror:0.00000	eval-merror:0.25926
# [373]	train-merror:0.00000	eval-merror:0.25926
# [374]	train-merror:0.00000	eval-merror:0.25926
# [375]	train-merror:0.00000	eval-merror:0.25926
# [376]	train-merror:0.00000	eval-merror:0.25926
# [377]	train-merror:0.00000	eval-merror:0.25926
# [378]	train-merror:0.00000	eval-merror:0.25926
# [379]	train-merror:0.00000	eval-merror:0.25926
# [380]	train-merror:0.00000	eval-merror:0.25926
# [381]	train-merror:0.00000	eval-merror:0.25926
# [382]	train-merror:0.00000	eval-merror:0.25926
# [383]	train-merror:0.00000	eval-merror:0.25926
# [384]	train-merror:0.00000	eval-merror:0.25926
# [385]	train-merror:0.00000	eval-merror:0.25926
# [386]	train-merror:0.00000	eval-merror:0.25926
# [387]	train-merror:0.00000	eval-merror:0.25926
# [388]	train-merror:0.00000	eval-merror:0.25926
# [389]	train-merror:0.00000	eval-merror:0.25926
# [390]	train-merror:0.00000	eval-merror:0.25926
# [391]	train-merror:0.00000	eval-merror:0.25926
# [392]	train-merror:0.00000	eval-merror:0.25926
# [393]	train-merror:0.00000	eval-merror:0.25926
# [394]	train-merror:0.00000	eval-merror:0.25926
# [395]	train-merror:0.00000	eval-merror:0.25926
# [396]	train-merror:0.00000	eval-merror:0.25926
# [397]	train-merror:0.00000	eval-merror:0.25926
# [398]	train-merror:0.00000	eval-merror:0.25926
# [399]	train-merror:0.00000	eval-merror:0.25926

# %%
print(1-0.19876)
# Out:
# 0.81481

# %%
print(1-0.16667)
# Out:
# 0.83333
